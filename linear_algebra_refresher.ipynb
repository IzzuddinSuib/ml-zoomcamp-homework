# %% [markdown]
# <a href="https://colab.research.google.com/github/IzzuddinSuib/ml-zoomcamp-homework/blob/main/linear_algebra_refresher.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install numpy

# %%
import numpy as np
import pandas as pd

# %%
u = np.array([2,4,5,6])
u
# Out:
# array([2, 4, 5, 6])

# %%
v = np.array([1,0,0,2])
v
# Out:
# array([1, 0, 0, 2])

# %%
u+v
# Out:
# array([3, 4, 5, 8])

# %%
2*u
# Out:
# array([ 4,  8, 10, 12])

# %%
# dot product

u*v
# Out:
# array([ 2,  0,  0, 12])

# %%
v.shape[0]
# Out:
# 4

# %%
# rvec * cvec

def vector_vector_multiplication(u,v):
  assert u.shape[0] == v.shape[0]

  n= u.shape[0]

  result = 0.0

  for i in range(n):
    result = result + u[i]*v[i]

  return result

# %%
vector_vector_multiplication(u,v)
# Out:
# np.float64(14.0)

# %%
u.dot(v)
# Out:
# np.int64(14)

# %%
# matrix vector multiplication

U = np.array([
    [2,4,5,6],
    [1,2,1,2],
    [3,1,2,1]
])
U
# Out:
# array([[2, 4, 5, 6],
#        [1, 2, 1, 2],
#        [3, 1, 2, 1]])

# %%
U.shape
# Out:
# (3, 4)

# %%
np.zeros(3)
# Out:
# array([0., 0., 0.])

# %%
def matrix_vector_multiplication(U,v):
  assert U.shape[1] == v.shape[0]

  num_rows = U.shape[0]

  result = np.zeros(num_rows)

  for i in range(num_rows):
    result[i] = vector_vector_multiplication(U[i],v)

  return result

# %%
matrix_vector_multiplication(U,v)
# Out:
# array([14.,  5.,  5.])

# %%
U.dot(v)
# Out:
# array([14,  5,  5])

# %%
V = np.array([
    [1,1,2],
    [0,0.5,1],
    [0,2,1],
    [2,1,0]
])
V
# Out:
# array([[1. , 1. , 2. ],
#        [0. , 0.5, 1. ],
#        [0. , 2. , 1. ],
#        [2. , 1. , 0. ]])

# %%
# matrix matrix multiplication

def matrix_matrix_multiplication(U,V):
  assert U.shape[1] == V.shape[0]

  num_rows = U.shape[0]
  num_cols = V.shape[1]

  result = np.zeros((num_rows,num_cols))

  for i in range(num_cols):
    vi = V[:,i]
    Uvi = matrix_vector_multiplication(U,vi)
    result[:,i] = Uvi

  return result

# %%
U
# Out:
# array([[2, 4, 5, 6],
#        [1, 2, 1, 2],
#        [3, 1, 2, 1]])

# %%
V
# Out:
# array([[1. , 1. , 2. ],
#        [0. , 0.5, 1. ],
#        [0. , 2. , 1. ],
#        [2. , 1. , 0. ]])

# %%
matrix_matrix_multiplication(U,V)
# Out:
# array([[14. , 20. , 13. ],
#        [ 5. ,  6. ,  5. ],
#        [ 5. ,  8.5,  9. ]])

# %%
U.dot(V)
# Out:
# array([[14. , 20. , 13. ],
#        [ 5. ,  6. ,  5. ],
#        [ 5. ,  8.5,  9. ]])

# %%
# Identity matrix

I = np.eye(3)
I
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])

# %%
V
# Out:
# array([[1. , 1. , 2. ],
#        [0. , 0.5, 1. ],
#        [0. , 2. , 1. ],
#        [2. , 1. , 0. ]])

# %%
V.dot(I)
# Out:
# array([[1. , 1. , 2. ],
#        [0. , 0.5, 1. ],
#        [0. , 2. , 1. ],
#        [2. , 1. , 0. ]])

# %%
# Matrix inverse

Vs = V[[0,1,2]]
Vs
# Out:
# array([[1. , 1. , 2. ],
#        [0. , 0.5, 1. ],
#        [0. , 2. , 1. ]])

# %%
Vs_inv = np.linalg.inv(Vs)
Vs_inv
# Out:
# array([[ 1.        , -2.        ,  0.        ],
#        [ 0.        , -0.66666667,  0.66666667],
#        [ 0.        ,  1.33333333, -0.33333333]])

# %%
Vs_inv.dot(Vs)
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])
